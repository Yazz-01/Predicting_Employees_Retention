# %%
# Dependencies

import pandas as pd
import numpy as np
import glob
import os
import timeit                                # To check performance
from datetime import datetime, date, time, timedelta
import matplotlib.pyplot as plt
import re

# %%
# Import CSV

tic = timeit.default_timer()                            # Monitor performance

ibm_df = pd.read_csv("../WA_Fn-UseC_-HR-Employee-Attrition.csv", header=0)

toc = timeit.default_timer()                            # Monitor performance
print(f'Time (in seconds) to import CSV file: {round(toc - tic, 2)}')
ibm_df
# Out:
# Time (in seconds) to import CSV file: 0.01
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                    1          2  Life Sciences              1
# 1                    8          1  Life Sciences              1
# 2                    2          2          Other              1
# 3                    3          4  Life Sciences              1
# 4                    2          1        Medical              1
# ...                ...        ...            ...            ...
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 0                  1  ...                         1            80
# 1                  2  ...                         4            80
# 2                  4  ...                         2            80
# 3                  5  ...                         3            80
# 4                  7  ...                         4            80
# ...              ...  ...                       ...           ...
# 1465            2061  ...                         3            80
# 1466            2062  ...                         1            80
# 1467            2064  ...                         2            80
# 1468            2065  ...                         4            80
# 1469            2068  ...                         1            80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0                  8                      0
# 1                    1                 10                      3
# 2                    0                  7                      3
# 3                    0                  8                      3
# 4                    1                  6                      3
# ...                ...                ...                    ...
# 1465                 1                 17                      3
# 1466                 1                  9                      5
# 1467                 1                  6                      0
# 1468                 0                 17                      3
# 1469                 0                  6                      3
#
#      WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                  1               6                  4
# 1                  3              10                  7
# 2                  3               0                  0
# 3                  3               8                  7
# 4                  3               2                  2
# ...              ...             ...                ...
# 1465               3               5                  2
# 1466               3               7                  7
# 1467               3               6                  2
# 1468               2               9                  6
# 1469               4               4                  3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 35 columns]

# %%
ibm_df_clean = ibm_df[['DistanceFromHome', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'TotalWorkingYears', 'TrainingTimesLastYear' ]]


ibm_df_clean
# Out:
#       DistanceFromHome  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0                    1                4        Single           5993
# 1                    8                2       Married           5130
# 2                    2                3        Single           2090
# 3                    3                3       Married           2909
# 4                    2                2       Married           3468
# ...                ...              ...           ...            ...
# 1465                23                4       Married           2571
# 1466                 6                1       Married           9991
# 1467                 4                2       Married           6142
# 1468                 2                2       Married           5390
# 1469                 8                3       Married           4404
#
#       TotalWorkingYears  TrainingTimesLastYear
# 0                     8                      0
# 1                    10                      3
# 2                     7                      3
# 3                     8                      3
# 4                     6                      3
# ...                 ...                    ...
# 1465                 17                      3
# 1466                  9                      5
# 1467                  6                      0
# 1468                 17                      3
# 1469                  6                      3
#
# [1470 rows x 6 columns]

# %%
ibm_df.to_csv("../static/js/data.csv", index=False)

# %%
ibm_df.to_json("../static/js/data.json", orient='index')
