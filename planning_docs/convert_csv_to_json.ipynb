# %%
# Dependencies

import pandas as pd
import numpy as np
import glob
import os
import timeit                                # To check performance
from datetime import datetime, date, time, timedelta
import matplotlib.pyplot as plt
import re

# %%
# Import CSV

tic = timeit.default_timer()                            # Monitor performance

ibm_df = pd.read_csv("../WA_Fn-UseC_-HR-Employee-Attrition.csv", header=0)

toc = timeit.default_timer()                            # Monitor performance
print(f'Time (in seconds) to import CSV file: {round(toc - tic, 2)}')
ibm_df
# Out:
# Time (in seconds) to import CSV file: 0.01
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
ibm_df_clean = ibm_df[['OverTime', 'MaritalStatus', 'Gender' , 'Department',  'NumCompaniesWorked', 'TotalWorkingYears',  ]]


ibm_df_clean
# Out:
#      OverTime MaritalStatus  Gender              Department  \
# 0         Yes        Single  Female                   Sales
# 1          No       Married    Male  Research & Development
# 2         Yes        Single    Male  Research & Development
# 3         Yes       Married  Female  Research & Development
# 4          No       Married    Male  Research & Development
# ...       ...           ...     ...                     ...
# 1465       No       Married    Male  Research & Development
# 1466       No       Married    Male  Research & Development
# 1467      Yes       Married    Male  Research & Development
# 1468       No       Married    Male                   Sales
# 1469       No       Married    Male  Research & Development
#
#       NumCompaniesWorked  TotalWorkingYears
# 0                      8                  8
# 1                      1                 10
# 2                      6                  7
# 3                      1                  8
# ...

# %%
# create a list of our conditions
conditions = [
    (ibm_df_clean['Department'] == 'Sales'),
    (ibm_df_clean['Department'] != 'Sales')
    ]

# create a list of the values we want to assign for each condition
values = ['Yes', 'No']

# %%
ibm_df_clean['SalesDpt'] = np.select(conditions, values)

# df['tier'] = np.select(conditions, values)
ibm_df_clean
# Out:
# <ipython-input-5-c8f34c9cab15>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ibm_df_clean['SalesDpt'] = np.select(conditions, values)
#      OverTime MaritalStatus  Gender              Department  \
# 0         Yes        Single  Female                   Sales
# 1          No       Married    Male  Research & Development
# 2         Yes        Single    Male  Research & Development
# 3         Yes       Married  Female  Research & Development
# 4          No       Married    Male  Research & Development
# ...       ...           ...     ...                     ...
# 1465       No       Married    Male  Research & Development
# 1466       No       Married    Male  Research & Development
# ...

# %%
ibm_df_clean2 = ibm_df_clean[['OverTime', 'MaritalStatus', 'Gender', 'SalesDpt', 'NumCompaniesWorked', 'TotalWorkingYears']]
ibm_df_clean2
# Out:
#      OverTime MaritalStatus  Gender SalesDpt  NumCompaniesWorked  \
# 0         Yes        Single  Female      Yes                   8
# 1          No       Married    Male       No                   1
# 2         Yes        Single    Male       No                   6
# 3         Yes       Married  Female       No                   1
# 4          No       Married    Male       No                   9
# ...       ...           ...     ...      ...                 ...
# 1465       No       Married    Male       No                   4
# 1466       No       Married    Male       No                   4
# 1467      Yes       Married    Male       No                   1
# 1468       No       Married    Male      Yes                   2
# 1469       No       Married    Male       No                   2
#
#       TotalWorkingYears
# 0                     8
# 1                    10
# 2                     7
# 3                     8
# 4                     6
# ...                 ...
# ...

# %%
ibm_df_clean2.to_csv("../static/js/data.csv", index=False)

# %%
# ibm_df.to_json("../static/js/data.json", orient='index')
