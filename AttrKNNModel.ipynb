# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
#'Age','Attrition','DistanceFromHome','EnvironmentSatisfaction','Gender','HourlyRate','JobLevel','JobSatisfaction','MaritalStatus',
#'MonthlyIncome','NumCompaniesWorked','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StockOptionLevel',
#'TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager'

features=['Age','DistanceFromHome','EnvironmentSatisfaction','Gender','HourlyRate','JobLevel','JobSatisfaction','MaritalStatus',
'MonthlyIncome','NumCompaniesWorked','PercentSalaryHike','PerformanceRating','RelationshipSatisfaction','StockOptionLevel',
'TotalWorkingYears','TrainingTimesLastYear','WorkLifeBalance','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager']

# %%
#select features
data=df[features]
data_binary_encoded = pd.get_dummies(data)
X=data_binary_encoded
y=pd.get_dummies(df['Attrition'])

# %%
#Splitting and scaling the data
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
#Train the model
#from sklearn import tree
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model = model.fit(X_train_scaled, y_train)
print(f"Training score: {model.score(X_train_scaled,y_train)}")
print(f"Test score: {model.score(X_test_scaled,y_test)}")
#print(classification_report(y_report, predictions, target_names=["red","blue"]))
# Out:
# Training score: 0.8738656987295825
# Test score: 0.8125
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-74c754acbb1f> in <module>
#       7 print(f"Training score: {model.score(X_train_scaled,y_train)}")
#       8 print(f"Test score: {model.score(X_test_scaled,y_test)}")
# ----> 9 print(model.classification_report(X_test_scaled,y_test))
#
# AttributeError: 'KNeighborsClassifier' object has no attribute 'classification_report'

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors':[3,5,7,9,11,13,15,17,19],
             'weights':['uniform','distance'],
             'metric':['euclidean','manhattan']}
grid = GridSearchCV(KNeighborsClassifier(), param_grid, verbose=3)
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=3, weights=distance; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=3, weights=distance; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=3, weights=distance; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=3, weights=distance; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=3, weights=distance; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=5, weights=distance; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=5, weights=distance; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=5, weights=distance; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=5, weights=distance; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=5, weights=distance; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=7, weights=distance; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=7, weights=distance; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=7, weights=distance; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=7, weights=distance; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=7, weights=distance; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=9, weights=distance; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=9, weights=distance; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=9, weights=distance; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=9, weights=distance; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=9, weights=distance; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=11, weights=distance; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=11, weights=distance; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=11, weights=distance; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=11, weights=distance; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=11, weights=distance; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=13, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=13, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=13, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=13, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=13, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=13, weights=distance; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=13, weights=distance; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=13, weights=distance; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=13, weights=distance; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=13, weights=distance; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=15, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=15, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=15, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=15, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=15, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=15, weights=distance; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=15, weights=distance; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=15, weights=distance; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=15, weights=distance; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=15, weights=distance; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=17, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=17, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=17, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=17, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=17, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=17, weights=distance; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=17, weights=distance; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=17, weights=distance; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=17, weights=distance; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=17, weights=distance; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=19, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=19, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=19, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=19, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=19, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=euclidean, n_neighbors=19, weights=distance; total time=   0.0s
# [CV 2/5] END metric=euclidean, n_neighbors=19, weights=distance; total time=   0.0s
# [CV 3/5] END metric=euclidean, n_neighbors=19, weights=distance; total time=   0.0s
# [CV 4/5] END metric=euclidean, n_neighbors=19, weights=distance; total time=   0.0s
# [CV 5/5] END metric=euclidean, n_neighbors=19, weights=distance; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=3, weights=distance; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=3, weights=distance; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=3, weights=distance; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=3, weights=distance; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=3, weights=distance; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=5, weights=distance; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=5, weights=distance; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=5, weights=distance; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=5, weights=distance; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=5, weights=distance; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=7, weights=distance; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=7, weights=distance; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=7, weights=distance; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=7, weights=distance; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=7, weights=distance; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=9, weights=distance; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=9, weights=distance; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=9, weights=distance; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=9, weights=distance; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=9, weights=distance; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=11, weights=distance; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=11, weights=distance; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=11, weights=distance; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=11, weights=distance; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=11, weights=distance; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=13, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=13, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=13, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=13, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=13, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=13, weights=distance; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=13, weights=distance; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=13, weights=distance; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=13, weights=distance; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=13, weights=distance; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=15, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=15, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=15, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=15, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=15, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=15, weights=distance; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=15, weights=distance; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=15, weights=distance; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=15, weights=distance; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=15, weights=distance; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=17, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=17, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=17, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=17, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=17, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=17, weights=distance; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=17, weights=distance; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=17, weights=distance; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=17, weights=distance; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=17, weights=distance; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=19, weights=uniform; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=19, weights=uniform; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=19, weights=uniform; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=19, weights=uniform; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=19, weights=uniform; total time=   0.0s
# [CV 1/5] END metric=manhattan, n_neighbors=19, weights=distance; total time=   0.0s
# [CV 2/5] END metric=manhattan, n_neighbors=19, weights=distance; total time=   0.0s
# [CV 3/5] END metric=manhattan, n_neighbors=19, weights=distance; total time=   0.0s
# [CV 4/5] END metric=manhattan, n_neighbors=19, weights=distance; total time=   0.0s
# [CV 5/5] END metric=manhattan, n_neighbors=19, weights=distance; total time=   0.0s
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'metric': ['euclidean', 'manhattan'],
#                          'n_neighbors': [3, 5, 7, 9, 11, 13, 15, 17, 19],
#                          'weights': ['uniform', 'distance']},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'metric': 'manhattan', 'n_neighbors': 15, 'weights': 'uniform'}
# 0.8529740847387906

# %%
model2=grid.best_estimator_

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model2, 
                   feature_names=iris.feature_names,  
                   class_names=iris.target_names,
                   filled=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b65cc52fdf94> in <module>
#       1 fig = plt.figure(figsize=(25,20))
# ----> 2 _ = tree.plot_tree(model2,
#       3                    feature_names=iris.feature_names,
#       4                    class_names=iris.target_names,
#       5                    filled=True)
#
# NameError: name 'tree' is not defined
